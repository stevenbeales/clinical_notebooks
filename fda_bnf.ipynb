# %% [markdown]
# # Get KEGG drug names data

# %%
import pandas as pd

#From http://www.kegg.jp/kegg/drug/

# problems with their list:
#    'Formaldehyde (USP); Formalin (JP17)' - this is in BNF but no INN or BAN
#    'Oxygen (JP17/USP)' - this is in BNF but no INN or BAN
# So - sometimes there is a BNF entry for things with no INN

name_systems = {
 'TN': 'Trade Name (example)',
 'JAN': 'Japanese Approved Name',
 'USAN': 'United States Adopted Name',
 'NF': 'National Formulary drug name',
 'INN': 'International Nonproprietary Name',
 'BAN': 'British Approved Name',
 'DCF': 'Dénomination commune française',
 'JP17': 'Japanese Pharmacopoeia, 17th edition',
 'USP': 'United States Pharmacopeia'}

url = 'http://rest.kegg.jp/list/drug'
data = pd.read_table(url, index_col=0, names = ['names'], header=0, sep="\t")
data = data[~pd.isnull(data['names'])]  # it includes nulls, for some reason

# %% [markdown]
# ## Extract various country-specific names to their own columns

# %%
import re

def foo(field, requested_system):
    if not pd.isnull(field):
        for alternative in field.split(";"):
            match = re.match(r'^(.*) \((.*)\)', alternative)
            if not match:
                # There are usually only INNs for the moiety rather than the salt, etc.
                # print "oops", alternative, "###", field
                continue
            name, systems = match.groups()
            for system in systems.split('/'):
                if system == requested_system:
                    return name
    return None
data['INN'] = data['names'].apply(lambda x: foo(x, 'INN'))
data['BAN'] = data['names'].apply(lambda x: foo(x, 'BAN'))
data['USAN'] = data['names'].apply(lambda x: foo(x, 'USAN'))

data['USP'] = data['names'].apply(lambda x: foo(x, 'USP'))
data['non-BAN'] = data['names'].apply(lambda x: foo(x, 'USP') or foo(x, 'USAN') or foo(x, 'INN')).str.upper()
data.head()
data[data['names'].str.contains('etamine')]
# Out:
#                                                        names  \
# dr:D00711    Ketamine hydrochloride (JP17/USP); Ketalar (TN)
# dr:D01411                     Lefetamine hydrochloride (JAN)
# dr:D01570  Iofetamine hydrochloride I 123 (USAN); N-Isopr...
# dr:D02074         Amphetamine sulfate (USP); Benzedrine (TN)
# dr:D02078  Dextroamphetamine sulfate (USP); Dexedrine (TN...
# dr:D02242  Methamphetamine hydrochloride (JP17/USP); Deso...
# dr:D02291                         Levmetamfetamine (USP/INN)
# dr:D02803                     Aletamine hydrochloride (USAN)
# dr:D02841                Altretamine (USP/INN); Hexalen (TN)
# dr:D03740      Dextroamphetamine (USAN); Dexamfetamine (INN)
# dr:D04473  Hydroxyamphetamine hydrobromide (USP); Paredri...
# dr:D04704                     Levamfetamine succinate (USAN)
# dr:D04747  Lisdexamfetamine dimesylate (USAN); Vyvanse (T...
# dr:D04826                                  Lycetamine (USAN)
# dr:D06146                     Tiletamine hydrochloride (USP)
# dr:D07114                               Etilamfetamine (INN)
# dr:D07283                              Esketamine (USAN/INN)
# dr:D07445      Amfetamine (INN); Amphetamine; Amfetamin (TN)
# dr:D07514                  Benzfetamine (INN); Benzphetamine
# dr:D07515            Benzfetamine hydrochloride; Didrex (TN)
# dr:D08098                         Ketamine (INN); Tekam (TN)
# dr:D08130                             Lisdexamfetamine (INN)
# dr:D08187               Metamfetamine (INN); Methamphetamine
# dr:D08596                                   Tiletamine (INN)
# dr:D10627                    Esketamine hydrochloride (USAN)
#
#                         INN   BAN                            USAN  \
# dr:D00711              None  None                            None
# dr:D01411              None  None                            None
# dr:D01570              None  None  Iofetamine hydrochloride I 123
# dr:D02074              None  None                            None
# dr:D02078              None  None                            None
# dr:D02242              None  None                            None
# dr:D02291  Levmetamfetamine  None                            None
# dr:D02803              None  None         Aletamine hydrochloride
# dr:D02841       Altretamine  None                            None
# dr:D03740     Dexamfetamine  None               Dextroamphetamine
# dr:D04473              None  None                            None
# dr:D04704              None  None         Levamfetamine succinate
# dr:D04747              None  None     Lisdexamfetamine dimesylate
# dr:D04826              None  None                      Lycetamine
# dr:D06146              None  None                            None
# dr:D07114    Etilamfetamine  None                            None
# dr:D07283        Esketamine  None                      Esketamine
# dr:D07445        Amfetamine  None                            None
# dr:D07514      Benzfetamine  None                            None
# dr:D07515              None  None                            None
# dr:D08098          Ketamine  None                            None
# dr:D08130  Lisdexamfetamine  None                            None
# dr:D08187     Metamfetamine  None                            None
# dr:D08596        Tiletamine  None                            None
# dr:D10627              None  None        Esketamine hydrochloride
#
#                                        USP                          non-BAN
# dr:D00711           Ketamine hydrochloride           KETAMINE HYDROCHLORIDE
# dr:D01411                             None                             None
# dr:D01570                             None   IOFETAMINE HYDROCHLORIDE I 123
# dr:D02074              Amphetamine sulfate              AMPHETAMINE SULFATE
# dr:D02078        Dextroamphetamine sulfate        DEXTROAMPHETAMINE SULFATE
# dr:D02242    Methamphetamine hydrochloride    METHAMPHETAMINE HYDROCHLORIDE
# dr:D02291                 Levmetamfetamine                 LEVMETAMFETAMINE
# dr:D02803                             None          ALETAMINE HYDROCHLORIDE
# dr:D02841                      Altretamine                      ALTRETAMINE
# dr:D03740                             None                DEXTROAMPHETAMINE
# dr:D04473  Hydroxyamphetamine hydrobromide  HYDROXYAMPHETAMINE HYDROBROMIDE
# dr:D04704                             None          LEVAMFETAMINE SUCCINATE
# dr:D04747                             None      LISDEXAMFETAMINE DIMESYLATE
# dr:D04826                             None                       LYCETAMINE
# dr:D06146         Tiletamine hydrochloride         TILETAMINE HYDROCHLORIDE
# dr:D07114                             None                   ETILAMFETAMINE
# dr:D07283                             None                       ESKETAMINE
# dr:D07445                             None                       AMFETAMINE
# dr:D07514                             None                     BENZFETAMINE
# dr:D07515                             None                             None
# dr:D08098                             None                         KETAMINE
# dr:D08130                             None                 LISDEXAMFETAMINE
# dr:D08187                             None                    METAMFETAMINE
# dr:D08596                             None                       TILETAMINE
# dr:D10627                             None         ESKETAMINE HYDROCHLORIDE

# %% [markdown]
# # Get FDA data

# %%
import requests
import subprocess
# from https://www.fda.gov/drugs/informationondrugs/ucm079750.htm#download
url = 'https://www.fda.gov/downloads/Drugs/InformationOnDrugs/UCM527389.zip'
r = requests.get(url, stream=True)
chunk_size = 2**16
with open('/tmp/pdf.zip', 'wb') as fd:
    for chunk in r.iter_content(chunk_size):
        fd.write(chunk)
subprocess.check_call('unzip /tmp/pdf.zip -d data/', shell=True)
# Out:
# 0

# %% [markdown]
# ## Turn it into just a list of ingredients

# %%
products_df = pd.read_table('data/Products.txt', sep="\t(?!$)")
all_us_ingredients = pd.DataFrame(
    products_df[~products_df.ActiveIngredient.str.contains(";")].ActiveIngredient.unique(),
    columns=['name'])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %% [markdown]
# ## Merge FDA ingredients with KEGG names

# %%
asd = all_us_ingredients.merge(data, left_on='name', right_on='non-BAN', how='inner')
asd.head()
# Out:
#                               name  \
# 0  HYDROXYAMPHETAMINE HYDROBROMIDE
# 1                    SULFAPYRIDINE
# 2                   HEPARIN SODIUM
# 3              HISTAMINE PHOSPHATE
# 4              BUTABARBITAL SODIUM
#
#                                                names                      INN  \
# 0  Hydroxyamphetamine hydrobromide (USP); Paredri...                     None
# 1        Sulfapyridine (USP/INN); Sulfapyridine (TN)            Sulfapyridine
# 2  Heparin sodium (JP17/USP/INN); Parnaparin sodi...           Heparin sodium
# 3  Histamine phosphate (USP); Histamine phosphate...                     None
# 4  Butabarbital sodium (USP); Secbutabarbital sod...   Secbutabarbital sodium
#
#     BAN  USAN                              USP  \
# 0  None  None  Hydroxyamphetamine hydrobromide
# 1  None  None                    Sulfapyridine
# 2  None  None                   Heparin sodium
# 3  None  None              Histamine phosphate
# 4  None  None              Butabarbital sodium
#
#                            non-BAN
# 0  HYDROXYAMPHETAMINE HYDROBROMIDE
# 1                    SULFAPYRIDINE
# 2                   HEPARIN SODIUM
# 3              HISTAMINE PHOSPHATE
# 4              BUTABARBITAL SODIUM

# %%
bnf_df = pd.DataFrame(
    pd.read_csv('data/bnf_codes.csv', 
                usecols=['BNF Chemical Substance'])['BNF Chemical Substance'].str.upper().unique(), 
    columns=['bnf_name'])

# %%
bnf_df.head()
# Out:
#                              bnf_name
# 0                     ALEXITOL SODIUM
# 1                          ALMASILATE
# 2                 ALUMINIUM HYDROXIDE
# 3  ALUMINIUM HYDROXIDE WITH MAGNESIUM
# 4                        HYDROTALCITE

# %%
us_only = asd.merge(bnf_df, left_on='non-BAN', right_on='bnf_name', how='right')

# %%
us_only.head()
# Out:
#                  name                                              names  \
# 0       SULFAPYRIDINE        Sulfapyridine (USP/INN); Sulfapyridine (TN)
# 1      HEPARIN SODIUM  Heparin sodium (JP17/USP/INN); Parnaparin sodi...
# 2       AMINOPHYLLINE  Aminophylline (USP/INN); Somophyllin (TN); The...
# 3  METHYLTESTOSTERONE  Methyltestosterone (JP17/USP/INN); Android (TN...
# 4      ERGOCALCIFEROL  Ergocalciferol (JP17/USP); Vitamin D2; Calcife...
#
#                   INN   BAN  USAN                 USP             non-BAN  \
# 0       Sulfapyridine  None  None       Sulfapyridine       SULFAPYRIDINE
# 1      Heparin sodium  None  None      Heparin sodium      HEPARIN SODIUM
# 2       Aminophylline  None  None       Aminophylline       AMINOPHYLLINE
# 3  Methyltestosterone  None  None  Methyltestosterone  METHYLTESTOSTERONE
# 4                None  None  None      Ergocalciferol      ERGOCALCIFEROL
#
#              bnf_name
# 0       SULFAPYRIDINE
# 1      HEPARIN SODIUM
# 2       AMINOPHYLLINE
# 3  METHYLTESTOSTERONE
# 4      ERGOCALCIFEROL

# %%
unmatched = us_only[pd.isnull(us_only['non-BAN'])]
unmatched[~unmatched.bnf_name.str.contains('DUMMY') & ~unmatched.bnf_name.str.contains('OTHER')]['bnf_name'].head(50)
# Out:
# 958                              ALEXITOL SODIUM
# 959                                   ALMASILATE
# 960                          ALUMINIUM HYDROXIDE
# 961           ALUMINIUM HYDROXIDE WITH MAGNESIUM
# 962                                 HYDROTALCITE
# 963                          MAGNESIUM CARBONATE
# 964     CO-MAGALDROX(MAGNESIUM/ALUMINIUM HYDROX)
# 965                              MAGNESIUM OXIDE
# 966                        MAGNESIUM TRISILICATE
# 967       ALUMINIUM & MAGNESIUM & ACT SIMETICONE
# 968                                   MAGALDRATE
# 969           ALUMINIUM & MAGNESIUM & OXETACAINE
# 970       CO-SIMALCITE (SIMETICONE/HYDROTALCITE)
# 971                          MAGNESIUM HYDROXIDE
# 972                                   SIMETICONE
# 973               CALCIUM CARBONATE & SIMETICONE
# 974                           MAGNESIUM SULPHATE
# 975                               SODIUM CITRATE
# 977                               GRIPE MIXTURES
# 979           ALGINIC ACID COMPOUND PREPARATIONS
# 980                            CALCIUM CARBONATE
# 981                         BISMUTH SUBCARBONATE
# 982     COMPOUND ALGINATES&PROP INDIGESTION PREP
# 983                                   CLEBOPRIDE
# 984                          HYOSCYAMINE SULFATE
# 985                           PINAVERIUM BROMIDE
# 986                               PHLOROGLUCINOL
# 987                             ALVERINE CITRATE
# 988                           AMBUTONIUM BROMIDE
# 989       ALVERINE CITRATE COMPOUND PREPARATIONS
# 990          COMPOUND ANTISPASMODIC PREPARATIONS
# 991                                      GENTIAN
# 992                        ATROPINE METHONITRATE
# 993                                    CISAPRIDE
# 994                         BELLADONNA ALKALOIDS
# 995                                    CLOVE OIL
# 996                  DICYCLOVERINE HYDROCHLORIDE
# 997      DICYCLOVERINE HCL COMPOUND PREPARATIONS
# 998                       GLYCOPYRRONIUM BROMIDE
# 999                        HYOSCINE BUTYLBROMIDE
# 1000                    MEBEVERINE HYDROCHLORIDE
# 1001                    PENTHIENATE METHOBROMIDE
# 1002                              PEPPERMINT OIL
# 1003                         PIPENZOLATE BROMIDE
# 1004                  PIPERIDOLATE HYDROCHLORIDE
# 1005                        POLDINE METILSULFATE
# 1006        MEBEVERINE HCL COMPOUND PREPARATIONS
# 1007         PIPENZOLATE BROMIDE COMPOUND PREP'S
# 1009                    PAPAVERINE HYDROCHLORIDE
# 1011                    CIMETIDINE WITH ALGINATE
# Name: bnf_name, dtype: object

# %% [markdown]
# This list demonstrates how hard the matching is likely to be. For example, it includes:
#
# * CALCIUM CARBONATE which is not listed as a drug in the FDA database but is an "active ingredient" in other drugs
# * SIMETICONE which is called SIMETHICONE in FDA database and is similarly not listed on its own
# * KETAMINE which is listed as KETAMINE HCL in the FDA database
